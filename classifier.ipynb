# %%
# %pip install librosa
# Out:
# 376.46s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached librosa-0.9.2-py3-none-any.whl (214 kB)
# ...
#   Using cached audioread-2.1.9.tar.gz (377 kB)
# ...
#   Using cached joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# ...
#      |████████████████████████████████| 10.7 MB 5.2 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached resampy-0.3.1-py3-none-any.whl (3.1 MB)
# ...
#   Using cached pooch-1.6.0-py3-none-any.whl (56 kB)
# ...
#      |████████████████████████████████| 2.3 MB 2.5 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
# ...
